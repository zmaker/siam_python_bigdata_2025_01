# %% [markdown]
# # Regressione lineare semplice

# %%
import sklearn

# %%
import numpy as np

# %%
c = np.random.uniform(low=-10, high=100, size = 20)
c = np.round(c, 2)
c
# Out:
# array([25.44, 45.97, 49.79, 17.65, 99.69, 41.6 , 66.01, 79.73, 90.9 ,
#        84.77, 71.68,  8.31, 86.03, 32.42, 47.25, 47.09, 45.98, 84.52,
#        34.87, 92.4 ])

# %%
f = (c*9/5) + 32
f = np.round(f, 2)
f
# Out:
# array([ 77.79, 114.75, 121.62,  63.77, 211.44, 106.88, 150.82, 175.51,
#        195.62, 184.59, 161.02,  46.96, 186.85,  90.36, 117.05, 116.76,
#        114.76, 184.14,  94.77, 198.32])

# %%
rumore = np.random.normal(0,2,f.shape)
f = f + rumore

# %%
import matplotlib.pyplot as plt
plt.scatter(c, f)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
X = np.array(c).reshape(-1, 1)
X
# Out:
# array([[25.44],
#        [45.97],
#        [49.79],
#        [17.65],
#        [99.69],
#        [41.6 ],
#        [66.01],
#        [79.73],
#        [90.9 ],
#        [84.77],
#        [71.68],
#        [ 8.31],
#        [86.03],
#        [32.42],
#        [47.25],
#        [47.09],
#        [45.98],
#        [84.52],
#        [34.87],
#        [92.4 ]])

# %%
y = f

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
model.predict([[25.0]])
# Out:
# array([76.30951364])

# %%
feat = X
x_prev = np.array([[100.0],[110.0],[120.0],[130.0],[140.0],[150.0]])
x_tot = np.concatenate((feat, x_prev))
target = y
prev = model.predict(x_tot)
plt.scatter(feat, target)
plt.plot(x_tot, prev, color="gray")
plt.scatter(x_prev, prev[-len(x_prev):])
